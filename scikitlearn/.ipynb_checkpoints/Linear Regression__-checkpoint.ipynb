# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprice.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600   68000
# 4  4000  725000

# %%
# %matplotlib notebook
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area, df.price, color='red', marker="+")
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [raw]
# reg = linear_model.LinearRegression()
# reg.fit(df[['area']], df.price)

# %%
reg.predict(np.array(3300).reshape(1, 1))
# Out:
# /home/luskoecute/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([502962.32876712])

# %%
reg.intercept_
# Out:
# 608178.0821917808

# %%
reg.coef_
# Out:
# array([-31.88356164])

# %%
# y=m*x+b
-31.88356164*3300+608178.0821917808
# Out:
# 502962.3287797808

# %%
areas = pd.read_csv('areas.csv')
areas
# Out:
#     area
# 0   1000
# 1   1500
# 2   2000
# 3   2500
# 4   3000
# 5   3500
# 6   4000
# 7   4500
# 8   5000
# 9   5500
# 10  6000
# 11  6500
# 12  7000

# %%
reg.predict(areas)
# Out:
# array([576294.52054795, 560352.73972603, 544410.95890411, 528469.17808219,
#        512527.39726027, 496585.61643836, 480643.83561644, 464702.05479452,
#        448760.2739726 , 432818.49315068, 416876.71232877, 400934.93150685,
#        384993.15068493])

# %%
p = reg.predict(areas)
areas['prices'] = p

# %%
areas
# Out:
#     area         prices
# 0   1000  576294.520548
# 1   1500  560352.739726
# 2   2000  544410.958904
# 3   2500  528469.178082
# 4   3000  512527.397260
# 5   3500  496585.616438
# 6   4000  480643.835616
# 7   4500  464702.054795
# 8   5000  448760.273973
# 9   5500  432818.493151
# 10  6000  416876.712329
# 11  6500  400934.931507
# 12  7000  384993.150685

# %%
plt.scatter(df.area, df.price, color='red', marker="+")
plt.plot(df.area, reg.predict(df[["area"]]), color="blue")
# Out:
# <img src="data:image/png;base64,..." width="639.85">
